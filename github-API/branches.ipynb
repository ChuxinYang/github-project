# %% [markdown]
# ### Sample code - branches count

# %%
import pandas as pd
merge = pd.read_csv('data/merge_bq_repo_name.csv') # merge_bq_repo_name is the repo name I merged 
merge.shape
# Out:
# (16467, 2)

# %%
merge.head(10)
# Out:
#                            repo_name   company_name
# 0       000webhost/000webhost-sdk-js     000webhost
# 1  100dayproject/polymer-web-example  100dayproject
# 2                 18F/18f-cf-release            18F
# 3                    18F/api-program            18F
# 4              18F/caddy-boshrelease            18F
# 5                      18F/cf-abacus            18F
# 6            18F/cf-meteor-buildpack            18F
# 7                  18F/cg-cf-release            18F
# 8                       18F/cg-style            18F
# 9                   18F/cg-style-gem            18F

# %%
merge_repo = list(merge['repo_name']) # get only repo name from dataset
len(merge_repo)
# Out:
# 16467

# %% [markdown]
# ### Create pickle to save data in every iteration

# %%
# -- save picle  
import pickle
filepath = 'branch_time.pkl'

def batch(time_list):
    
    with open(filepath, 'ab') as f:
        pickle.dump(time_list, f)

# %% [markdown]
# ### Scrape data using github API

# %%
import requests
import time
import json

auth = ('ChuxinYang','7fa8727d5edc03fe9a4af13c95edf843b7371879')

branch_time = []

for j in range(len(merge_repo)):

    page = 1
    while True: 
        
        # use github API to scrape data
        get = requests.get('https://api.github.com/repos/'+ str(merge_repo[j]) +'/branches?page='+ str(page) +'&per_page=100/access_tokens',
                      auth = auth)
        get_json = json.loads(get.text)
        time.sleep(1) # rate limit
        
        # test if this repo still exist
        if type(get_json) == dict:
            break
            
        else:
            if len(get_json) == 0: # if there is nothing inside, break out of the loop and look for next repo
                break
 
                
            for i in range(len(get_json)):

                repo_tuple = tuple([merge_repo[j]]) # save the repo name first
                repo_tuple += tuple([get_json[i]['name']]) # save the branch name
                repo_tuple += tuple([get_json[i]['commit']['sha']]) # save the sha
                get2 = requests.get('https://api.github.com/repos/'+ str(merge_repo[j]) +'/commits/'+str(get_json[i]['commit']['sha'] + '?page='+ str(page) +'&per_page=100/access_tokens'),auth=auth)
                get2_json = json.loads(get2.text)
                repo_tuple += tuple([get2_json["commit"]["author"]["date"]]) # save the author date
                repo_tuple += tuple([get2_json["commit"]["committer"]["date"]]) # save the committer date first
                batch(repo_tuple) # call batch function to save repo_tuple in a pickle file
                time.sleep(1) # rate limit
                
            page += 1 
    print(j) # print which repo we are scraping
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Open pickle file and read data

# %%
import pandas as pd
import pickle
colnames = ['repo_name', 'branch_name', 'sha', 'commit_author_date','commit_committer_date'] # set column names

info = []
with open('branch_time.pkl', 'rb') as fr:
    try:
        while True:
            info.append(pickle.load(fr))
    except EOFError:
        pass
    
repo_info = pd.DataFrame(info, columns=colnames)
repo_info
# Out:
#                             repo_name                     branch_name  \
# 0        000webhost/000webhost-sdk-js                          master
# 1   100dayproject/polymer-web-example                          master
# 2                  18F/18f-cf-release                        bump-uaa
# 3                  18F/18f-cf-release                          master
# 4                  18F/18f-cf-release                     uaa-warning
# 5                  18F/18f-cf-release  update-even-more-from-upstream
# 6                     18F/api-program                       18f-pages
# 7                     18F/api-program                    guides-style
# 8                     18F/api-program       leah-edits2-merge-attempt
# 9                     18F/api-program                    leah-updates
# 10                    18F/api-program           seed-project-material
# 11              18F/caddy-boshrelease                          master
# 12                      18F/cf-abacus                       cg-v0.0.4
# 13                      18F/cf-abacus                  cg-v0.0.5-rc.1
# 14                      18F/cf-abacus                          master
# 15                      18F/cf-abacus                         patch-1
# 16       000webhost/000webhost-sdk-js                          master
# 17  100dayproject/polymer-web-example                          master
# 18                 18F/18f-cf-release                        bump-uaa
# 19                 18F/18f-cf-release                          master
# 20                 18F/18f-cf-release                     uaa-warning
# 21                 18F/18f-cf-release  update-even-more-from-upstream
# 22                    18F/api-program                       18f-pages
# 23                    18F/api-program                    guides-style
# 24                    18F/api-program       leah-edits2-merge-attempt
# 25                    18F/api-program                    leah-updates
# 26                    18F/api-program           seed-project-material
# 27       000webhost/000webhost-sdk-js                          master
# 28  100dayproject/polymer-web-example                          master
# 29                 18F/18f-cf-release                        bump-uaa
# 30                 18F/18f-cf-release                          master
# 31                 18F/18f-cf-release                     uaa-warning
# 32                 18F/18f-cf-release  update-even-more-from-upstream
# 33                    18F/api-program                       18f-pages
# 34                    18F/api-program                    guides-style
# 35                    18F/api-program       leah-edits2-merge-attempt
# 36                    18F/api-program                    leah-updates
# 37                    18F/api-program           seed-project-material
# 38              18F/caddy-boshrelease                          master
# 39                      18F/cf-abacus                       cg-v0.0.4
# 40                      18F/cf-abacus                  cg-v0.0.5-rc.1
# 41                      18F/cf-abacus                          master
# 42                      18F/cf-abacus                         patch-1
#
#                                          sha    commit_author_date  \
# 0   1fbf6030ffc603848901a499797af545b51de931  2020-01-08T10:55:57Z
# 1   56e634379f51e336fab36b3718a2e0dbf4d8f1ee  2016-03-31T02:55:24Z
# 2   c93512c41a1b5e2a43352ddbb005c33ed9287f43  2017-02-10T14:35:33Z
# 3   4b40b8d13d1cfcfb0d81275092f358b3152b0b78  2017-03-21T17:23:16Z
# 4   84b25e94f3be4cfe55093226fa9ca74d017002d6  2017-03-13T19:54:06Z
# 5   c558e0a2c7f41c17273268322985694d18f5a86a  2016-12-13T15:51:32Z
# 6   4e0f798be696950c4476ef273db2e794c85818cf  2017-04-27T17:09:28Z
# 7   8479d9dcf131e48270a4bb5fcb10d5437aa1b80c  2015-09-02T18:43:42Z
# 8   4853c7ea9adf61b34e1e8474d410fc000bb7e5a2  2016-08-31T02:37:01Z
# 9   e15287200087ce075bba4e1364a3ed72d2e94f20  2016-08-06T18:57:50Z
# 10  23a2d79ae87a3c9bc22c7d4745bcd7f6327bcfb6  2016-06-22T19:47:04Z
# 11  7beb07184fbfc495376eb8b884acb486281407d7  2016-02-07T04:12:07Z
# 12  5d106fb472a3387808477a65c647b09f2e05816a  2016-02-26T18:35:13Z
# 13  84b9d2f782754085f95e36bff33c77bc43e0057c  2016-03-14T20:31:22Z
# 14  4b11c14b09f56ee7cd46901244bde88bf3701a92  2016-03-14T19:37:14Z
# 15  fbdaa5b6ea5a53700f94661176d3819b67d58781  2016-02-03T20:26:50Z
# 16  1fbf6030ffc603848901a499797af545b51de931  2020-01-08T10:55:57Z
# 17  56e634379f51e336fab36b3718a2e0dbf4d8f1ee  2016-03-31T02:55:24Z
# 18  c93512c41a1b5e2a43352ddbb005c33ed9287f43  2017-02-10T14:35:33Z
# 19  4b40b8d13d1cfcfb0d81275092f358b3152b0b78  2017-03-21T17:23:16Z
# 20  84b25e94f3be4cfe55093226fa9ca74d017002d6  2017-03-13T19:54:06Z
# 21  c558e0a2c7f41c17273268322985694d18f5a86a  2016-12-13T15:51:32Z
# 22  4e0f798be696950c4476ef273db2e794c85818cf  2017-04-27T17:09:28Z
# 23  8479d9dcf131e48270a4bb5fcb10d5437aa1b80c  2015-09-02T18:43:42Z
# 24  4853c7ea9adf61b34e1e8474d410fc000bb7e5a2  2016-08-31T02:37:01Z
# 25  e15287200087ce075bba4e1364a3ed72d2e94f20  2016-08-06T18:57:50Z
# 26  23a2d79ae87a3c9bc22c7d4745bcd7f6327bcfb6  2016-06-22T19:47:04Z
# 27  1fbf6030ffc603848901a499797af545b51de931  2020-01-08T10:55:57Z
# 28  56e634379f51e336fab36b3718a2e0dbf4d8f1ee  2016-03-31T02:55:24Z
# 29  c93512c41a1b5e2a43352ddbb005c33ed9287f43  2017-02-10T14:35:33Z
# 30  4b40b8d13d1cfcfb0d81275092f358b3152b0b78  2017-03-21T17:23:16Z
# 31  84b25e94f3be4cfe55093226fa9ca74d017002d6  2017-03-13T19:54:06Z
# 32  c558e0a2c7f41c17273268322985694d18f5a86a  2016-12-13T15:51:32Z
# 33  4e0f798be696950c4476ef273db2e794c85818cf  2017-04-27T17:09:28Z
# 34  8479d9dcf131e48270a4bb5fcb10d5437aa1b80c  2015-09-02T18:43:42Z
# 35  4853c7ea9adf61b34e1e8474d410fc000bb7e5a2  2016-08-31T02:37:01Z
# 36  e15287200087ce075bba4e1364a3ed72d2e94f20  2016-08-06T18:57:50Z
# 37  23a2d79ae87a3c9bc22c7d4745bcd7f6327bcfb6  2016-06-22T19:47:04Z
# 38  7beb07184fbfc495376eb8b884acb486281407d7  2016-02-07T04:12:07Z
# 39  5d106fb472a3387808477a65c647b09f2e05816a  2016-02-26T18:35:13Z
# 40  84b9d2f782754085f95e36bff33c77bc43e0057c  2016-03-14T20:31:22Z
# 41  4b11c14b09f56ee7cd46901244bde88bf3701a92  2016-03-14T19:37:14Z
# 42  fbdaa5b6ea5a53700f94661176d3819b67d58781  2016-02-03T20:26:50Z
#
#    commit_committer_date
# 0   2020-01-08T10:55:57Z
# 1   2016-03-31T02:55:24Z
# 2   2017-02-10T14:35:33Z
# 3   2017-03-21T17:23:16Z
# 4   2017-03-13T19:54:06Z
# 5   2016-12-13T15:51:32Z
# 6   2017-04-27T17:09:28Z
# 7   2015-09-02T18:43:42Z
# 8   2016-08-31T02:37:01Z
# 9   2016-08-06T18:57:50Z
# 10  2016-06-22T19:47:04Z
# 11  2016-02-07T04:12:07Z
# 12  2016-02-26T18:35:13Z
# 13  2016-03-14T20:31:22Z
# 14  2016-03-14T19:40:48Z
# 15  2016-02-03T20:26:50Z
# 16  2020-01-08T10:55:57Z
# 17  2016-03-31T02:55:24Z
# 18  2017-02-10T14:35:33Z
# 19  2017-03-21T17:23:16Z
# 20  2017-03-13T19:54:06Z
# 21  2016-12-13T15:51:32Z
# 22  2017-04-27T17:09:28Z
# 23  2015-09-02T18:43:42Z
# 24  2016-08-31T02:37:01Z
# 25  2016-08-06T18:57:50Z
# 26  2016-06-22T19:47:04Z
# 27  2020-01-08T10:55:57Z
# 28  2016-03-31T02:55:24Z
# 29  2017-02-10T14:35:33Z
# 30  2017-03-21T17:23:16Z
# 31  2017-03-13T19:54:06Z
# 32  2016-12-13T15:51:32Z
# 33  2017-04-27T17:09:28Z
# 34  2015-09-02T18:43:42Z
# 35  2016-08-31T02:37:01Z
# 36  2016-08-06T18:57:50Z
# 37  2016-06-22T19:47:04Z
# 38  2016-02-07T04:12:07Z
# 39  2016-02-26T18:35:13Z
# 40  2016-03-14T20:31:22Z
# 41  2016-03-14T19:40:48Z
# 42  2016-02-03T20:26:50Z
