# %% [markdown]
# ### Sample code - stargazers count

# %%
import pandas as pd
merge = pd.read_csv('data/merge_bq_repo_name.csv') # merge_bq_repo_name is the repo name I merged 
merge.shape
# Out:
# (16467, 2)

# %%
merge.head(10)
# Out:
#                            repo_name   company_name
# 0       000webhost/000webhost-sdk-js     000webhost
# 1  100dayproject/polymer-web-example  100dayproject
# 2                 18F/18f-cf-release            18F
# 3                    18F/api-program            18F
# 4              18F/caddy-boshrelease            18F
# 5                      18F/cf-abacus            18F
# 6            18F/cf-meteor-buildpack            18F
# 7                  18F/cg-cf-release            18F
# 8                       18F/cg-style            18F
# 9                   18F/cg-style-gem            18F

# %%
merge_repo = list(merge['repo_name']) # get only repo name from dataset
len(merge_repo)
# Out:
# 16467

# %% [markdown]
# ### Create pickle to save data in every iteration

# %%
# -- save picle  
import pickle
filepath = 'stargazer_time.pkl'

def batch(time_list):
    
    with open(filepath, 'ab') as f:
        pickle.dump(time_list, f)

# %% [markdown]
# ### Scrape data using github API

# %%
import requests
import time
import json


auth = ('ChuxinYang','b5b61b3346c994d7939ace05f52a3efcdd512066') 

stargazer_time = []

for j in range(len(merge_repo)):

    
    page = 1
    while True: 
        
        # use github API to scrape data
        get = requests.get('https://api.github.com/repos/'+ str(merge_repo[j]) +'/stargazers?page='+ str(page) +'&per_page=100/access_tokens',
                    headers={'Accept': 'application/vnd.github.v3.star+json'},
                      auth = auth)
        get_json = json.loads(get.text)
        time.sleep(2) # rate limit
        
        # test if this repo still exist
        if type(get_json) == dict:
            break
            
        else:
            if len(get_json) == 0: # if there is nothing inside, break out of the loop and look for next repo
                break
 
                
            for i in range(len(get_json)):

                repo_tuple = tuple([merge_repo[j]]) # save the repo name first
                repo_tuple += tuple([get_json[i]['user']['login']]) # save the stargazer name
                repo_tuple += tuple([get_json[i]['user']['id']]) # save the stargazer id
                repo_tuple += tuple([get_json[i]['starred_at']]) # save the starred at time

                batch(repo_tuple) # call batch function to save repo_tuple in a pickle file
                    
            page += 1 
    print(j) # print which repo we are scraping
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Open pickle file and read data

# %%
import pandas as pd 
import pickle
colnames = ['repo_name', 'stargazer_name','stargazer_id','starred_at_time'] # set column names

info = []
with open('stargazer_time.pkl', 'rb') as fr:
    try:
        while True:
            info.append(pickle.load(fr))
    except EOFError:
        pass
    
repo_info = pd.DataFrame(info, columns=colnames)
repo_info
# Out:
#                             repo_name stargazer_name  stargazer_id  \
# 0        000webhost/000webhost-sdk-js    Lazymuxhost      49286156
# 1   100dayproject/polymer-web-example    kimthangatm       7090588
# 2   100dayproject/polymer-web-example       lephuhai       7351351
# 3   100dayproject/polymer-web-example    trquoccuong       7078282
# 4                  18F/18f-cf-release       rogeruiz        706004
# 5                  18F/18f-cf-release  rememberlenny       1332366
# 6                     18F/api-program     leahbannon       4323988
# 7                     18F/api-program       adelevie         86790
# 8                     18F/api-program       konklone          4592
# 9                     18F/api-program          parkr        237985
# 10                    18F/api-program       pdhoward       7431751
# 11                    18F/api-program  anthonygarvan       2559082
# 12                    18F/api-program    muradbiskin         22898
# 13                    18F/api-program     angusshire       5877145
# 14                    18F/api-program         csbndc      14223213
# 15                    18F/api-program    sivartravis        430323
# 16                    18F/api-program      djeraseit        935880
# 17                    18F/api-program         rdm3an      14006709
# 18       000webhost/000webhost-sdk-js    Lazymuxhost      49286156
# 19  100dayproject/polymer-web-example    kimthangatm       7090588
# 20  100dayproject/polymer-web-example       lephuhai       7351351
# 21  100dayproject/polymer-web-example    trquoccuong       7078282
# 22       000webhost/000webhost-sdk-js    Lazymuxhost      49286156
# 23  100dayproject/polymer-web-example    kimthangatm       7090588
# 24  100dayproject/polymer-web-example       lephuhai       7351351
# 25  100dayproject/polymer-web-example    trquoccuong       7078282
# 26                 18F/18f-cf-release       rogeruiz        706004
# 27                 18F/18f-cf-release  rememberlenny       1332366
# 28                    18F/api-program     leahbannon       4323988
# 29                    18F/api-program       adelevie         86790
# 30                    18F/api-program       konklone          4592
# 31                    18F/api-program          parkr        237985
# 32                    18F/api-program       pdhoward       7431751
# 33                    18F/api-program  anthonygarvan       2559082
# 34                    18F/api-program    muradbiskin         22898
# 35                    18F/api-program     angusshire       5877145
# 36                    18F/api-program         csbndc      14223213
# 37                    18F/api-program    sivartravis        430323
# 38                    18F/api-program      djeraseit        935880
# 39                    18F/api-program         rdm3an      14006709
#
#          starred_at_time
# 0   2019-06-18T23:36:11Z
# 1   2016-03-28T06:03:17Z
# 2   2016-03-28T06:55:19Z
# 3   2016-03-30T14:09:13Z
# 4   2016-12-08T18:04:25Z
# 5   2017-03-03T18:12:03Z
# 6   2015-02-07T19:58:56Z
# 7   2015-02-07T20:56:33Z
# 8   2015-02-08T05:38:35Z
# 9   2015-02-08T05:51:12Z
# 10  2015-05-13T15:04:49Z
# 11  2015-09-04T19:29:20Z
# 12  2015-09-13T21:26:58Z
# 13  2015-11-08T17:38:47Z
# 14  2016-04-28T18:52:36Z
# 15  2016-05-04T22:38:31Z
# 16  2016-06-07T23:53:02Z
# 17  2019-07-08T17:09:51Z
# 18  2019-06-18T23:36:11Z
# 19  2016-03-28T06:03:17Z
# 20  2016-03-28T06:55:19Z
# 21  2016-03-30T14:09:13Z
# 22  2019-06-18T23:36:11Z
# 23  2016-03-28T06:03:17Z
# 24  2016-03-28T06:55:19Z
# 25  2016-03-30T14:09:13Z
# 26  2016-12-08T18:04:25Z
# 27  2017-03-03T18:12:03Z
# 28  2015-02-07T19:58:56Z
# 29  2015-02-07T20:56:33Z
# 30  2015-02-08T05:38:35Z
# 31  2015-02-08T05:51:12Z
# 32  2015-05-13T15:04:49Z
# 33  2015-09-04T19:29:20Z
# 34  2015-09-13T21:26:58Z
# 35  2015-11-08T17:38:47Z
# 36  2016-04-28T18:52:36Z
# 37  2016-05-04T22:38:31Z
# 38  2016-06-07T23:53:02Z
# 39  2019-07-08T17:09:51Z
